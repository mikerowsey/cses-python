# %%
import introductory_problems.apple_division as problem

# %%
data = b"""
5
3 2 7 4 1
""".split()

# %%
result = problem.solve(iter(data))

# %%
# %timeit problem.solve(iter(data))
# Out:
# 2.28 μs ± 35.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

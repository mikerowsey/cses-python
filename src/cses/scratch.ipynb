# %%
import introductory_problems.gray_code as problem

# %%
data = b"""
2
""".split()

# %%
problem.solve(iter(data))
# Out:
# '00\n01\n11\n10'

# %%
# %timeit problem.solve(iter(data))
# Out:
# 255 ns ± 0.861 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

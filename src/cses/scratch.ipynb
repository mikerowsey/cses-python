# %%
import introductory_problems.tower_of_hanoi as problem

# %%
data = b"""
2
""".split()

# %%
problem.solve(iter(data))
# Out:
# '3\n1 2\n1 3\n2 3'

# %%
# %timeit problem.solve(iter(data))
# Out:
# 378 ns ± 1.96 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

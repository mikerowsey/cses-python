# %%
import two_sets as problem

# %%
data = b"""
7
""".split()

# %%
problem.solve(iter(data))
# Out:
# 'YES\n3\n7 4 3\n4\n6 5 2 1'

# %%
# %timeit problem.solve(iter(data))
# Out:
# 974 ns ± 2.97 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

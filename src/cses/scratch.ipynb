# %%
# import introductory_problems.creating_strings as problem

# %%
data = b"""
AABBCCDDEE
""".split()

# %%
# problem.solve(iter(data))

# %%
import introductory_problems.creating_strings as problem
# %timeit problem.solve(iter(data))
# Out:
# 275 ms ± 1.92 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import introductory_problems.creating_strings2 as problem
# %timeit problem.solve(iter(data))
# Out:
# 70.7 ms ± 257 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

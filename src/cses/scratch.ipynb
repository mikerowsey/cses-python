# %%
import mathematics.fibonacci as problem

# %%
data = b"""
10
""".split()

# %%
problem.solve(iter(data))
# Out:
# '55'

# %%
# %timeit problem.solve(iter(data))
# Out:
# 1.34 μs ± 5.38 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

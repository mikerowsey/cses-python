# %%
import introductory_problems.creating_strings_itertools as iter_tools
import introductory_problems.creating_strings_recursive as recursive

# %%
data = b"""
lmkikjbahca
""".split()

# %%
result = iter_tools.solve(iter(data))

# %%
# %timeit iter_tools.solve(iter(data))
# Out:
# 10.7 s ± 70.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit recursive.solve(iter(data))
# Out:
# 9.78 s ± 14 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

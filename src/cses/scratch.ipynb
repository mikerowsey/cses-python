# %%
import introductory_problems.chessboard_and_queens as problem

# %%
data = b"""

input
........
........
........
........
........
...
""".split()

# %%
result = problem.solve(iter(data))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = problem.solve(iter(data))
#
# File ~/repos/cses-python/src/cses/introductory_problems/chessboard_and_queens.py:5, in solve(it)
#       4 def solve(it) -> str:
# ----> 5     board = [ns(it) for _ in range(8)]
#       6     return "\n".join(board)
#
# File ~/repos/cses-python/src/cses/introductory_problems/chessboard_and_queens.py:18, in ns(it)
#      17 def ns(it) -> str:
# ---> 18     return next(it).decode()
#
# StopIteration:

# %%
# %timeit problem.solve(iter(data))
